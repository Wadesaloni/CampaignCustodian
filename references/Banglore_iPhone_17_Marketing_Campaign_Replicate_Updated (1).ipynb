# %% [markdown]
# # iPhone 17 Marketing Campaign - CrewAI Demo (Replicate)
#
# ---
#
# ## 🧩 Problem Statement
#
# Traditional marketing campaign creation for product launches like the **iPhone 17** is time-consuming, expensive, and requires coordination across multiple specialized teams.
#
# A typical campaign takes weeks and involves:
# - Market researchers analyzing competitors and audience
# - Content writers crafting messaging and copy
# - Social media managers designing platform strategies
# - Multiple revision cycles and team meetings
#
# 💰 **Cost:** $50k-60k
#
# ⏱️ **Time:** 4–6 weeks for a comprehensive campaign
#
# Small businesses and startups often can't afford this process.
#
# ---
#
# ## 💡 Solution
#
# An **AI-powered autonomous marketing crew** using **CrewAI** that can generate a complete, professional marketing campaign in **minutes instead of weeks**, at a fraction of the cost.
#
# ---
#
# ## 📘 Scope
#
# This project demonstrates how AI agents can collaborate to create:
#
# 1. **Market Research:** Competitor analysis, target audience, feature analysis
# 2. **Brand Content:** Tagline, product description, unique selling propositions
# 3. **Social Strategy:** Instagram posts, Twitter threads, TikTok video concepts
#
# The system uses:
# - **Real-time web search (Tavily)** for current market data
# - **Replicate AI** for intelligent content generation
# - **CrewAI framework** for multi-agent collaboration
#
# ---
#
# ## 🎯 Objectives
#
# ### Primary Objectives
# 1. Automate end-to-end marketing campaign creation
# 2. Reduce campaign development time from **weeks to minutes**
# 3. Generate **professional-quality, actionable marketing materials**
#
# ### Secondary Objectives
# 1. Demonstrate **AI agent collaboration** and task delegation
# 2. Show **real-time web research integration** with AI
# 3. Prove AI can **match human creativity** in marketing
# 4. Create **reusable frameworks** for any product launch
#
# ---
#
# ## 📊 Success Metrics
#
# | Metric | Target |
# |:--|:--|
# | Campaign generation time | < 5 minutes |
# | Deliverables included | Research, Content, Social |
# | Content quality | Real-world ready |
# | Human intervention | 0 after setup |
#
# ---
#
# ## 👥 Target Users
#
# - Startup founders launching new products
# - Small businesses with limited marketing budgets
# - Marketing agencies handling multiple clients
# - Product managers needing quick campaign drafts
# - Students learning AI and marketing automation
#
# ---
#
# ## 🤖 What We're Building
#
# We're creating an **autonomous AI marketing team** that:
#
# ### 1. Researches like a human analyst
# - Searches the web for iPhone 17 specifications
# - Analyzes competitors (*Samsung Galaxy S25, Google Pixel 10*)
# - Identifies target demographics and preferences
# - Delivers data-driven insights
#
# ### 2. Creates like a human copywriter
# - Crafts emotional, memorable taglines
# - Writes compelling product narratives
# - Develops benefit-focused messaging
# - Ensures brand consistency
#
# ### 3. Strategizes like a human social media manager
# - Designs platform-specific content
# - Creates viral-worthy post concepts
# - Develops engagement strategies
# - Plans multi-channel campaigns
#
# 🧠 All agents work **sequentially**, building on each other's output — just like a real marketing team would collaborate.
#
# ---
#
# ## 🚀 Innovation
#
# - First **fully autonomous marketing campaign generator**
# - **Real-time web integration** ensures current, accurate data
# - **Multi-agent collaboration** mimics human team dynamics
# - **Cost-effective** alternative to traditional agencies
# - **Scalable** to any product or industry
#
# ---
#
# ## ⚠️ Limitations
#
# - Requires API keys (Replicate, Tavily)
# - Output quality depends on **prompt engineering**
# - May need **human review** for brand-specific tone
# - Cannot execute campaigns (only generates strategy)
# - Limited to **text-based content** (no graphics/video)

# %%
# Install required packages
# ! pip install crewai crewai-tools python-dotenv replicate tavily-python

# %%
# pip install litellm langchain-openai

# %%
# pip install pandas

# %%
# ============================================
# IMPORTS
# ============================================
import os
import pandas as pd 
from dotenv import load_dotenv
from crewai import Agent, Task, Crew, Process, LLM
from crewai.tools import tool
from tavily import TavilyClient

# %%
# ============================================
# LOAD ENVIRONMENT VARIABLES
# ============================================
load_dotenv()
# Out:
# False

# %%
# ============================================
# VERIFY API KEYS
# ============================================
# Verify API keys
if not os.getenv("REPLICATE_API_TOKEN"):
    raise ValueError("REPLICATE_API_TOKEN not found in .env file!")
if not os.getenv("TAVILY_API_KEY"):
    raise ValueError("TAVILY_API_KEY not found in .env file!")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

print("✓ Environment variables loaded successfully!")
print(f"✓ Replicate Token: {os.getenv('REPLICATE_API_TOKEN')[:10]}...")
print(f"✓ Tavily API Key: {os.getenv('TAVILY_API_KEY')[:10]}...")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 6
#       1 # ============================================
#       2 # VERIFY API KEYS
#       3 # ============================================
#       4 # Verify API keys
#       5 if not os.getenv("REPLICATE_API_TOKEN"):
# ----> 6     raise ValueError("REPLICATE_API_TOKEN not found in .env file!")
#       7 if not os.getenv("TAVILY_API_KEY"):
#       8     raise ValueError("TAVILY_API_KEY not found in .env file!")
#
# ValueError: REPLICATE_API_TOKEN not found in .env file!

# %%
# ============================================
# INITIALIZE REPLICATE LLM
# ============================================

# Initialize Replicate LLM using CrewAI's LLM class
# You can choose from various models on Replicate
llm = LLM(
    model="replicate/openai/gpt-4o",  # Premium model for best results
    api_key=os.getenv("REPLICATE_API_TOKEN"),
    temperature=0.7
)

print("✓ Replicate LLM initialized successfully!")
print("Model: openai/gpt-4o")
# Out:
# ✓ Replicate LLM initialized successfully!
# Model: openai/gpt-4o

# %%
# ============================================
# INITIALIZE OpenAi LLM
# ============================================

llm = LLM(
    model="gpt-4o",  # Using direct OpenAI provider
    api_key=OPENAI_API_KEY,
    temperature=0.7
)


print("✓ OpenAi LLM initialized successfully!")
print("Model: openai/gpt-4o")
# Out:
# ✓ OpenAi LLM initialized successfully!
# Model: openai/gpt-4o

# %%
# ============================================
# TEST TAVILY SEARCH
# ============================================
query = "iPhone 17 features specifications"
client = TavilyClient(api_key=os.getenv("TAVILY_API_KEY"))
results = client.search(
        query=query, 
        max_results=5,
        search_depth="advanced",  # More comprehensive results
        include_domains=[],
        exclude_domains=[],
        country="india"  # India country code
    )
print(f"✓ Tavily search test successful! Found {len(results.get('results', []))} results")
print(results)
# Out:
# ✓ Tavily search test successful! Found 5 results
# {'query': 'iPhone 17 features specifications', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.bajajfinserv.in/apple-iphone-17-price-in-india', 'title': 'Apple iPhone 17 - Price in India, Features and Specifications', 'content': 'The iPhone 17 features a 6.3-inch Super Retina XDR OLED display with HDR10 and Dolby Vision support. It offers a peak brightness of 3,000 nits and a 120Hz adaptive refresh rate for smooth scrolling and gaming.\n\n|  |  |\n --- |\n| Feature | Details |\n| Type | Super Retina XDR OLED |\n| Size | 6.3-inch |\n| Resolution | 2622 x 1206 pixels |\n| Refresh rate | 120Hz ProMotion |\n| Brightness | Up to 3,000 nits peak |\n| HDR support | HDR10, Dolby Vision |\n| Protection | Ceramic Shield 2 | [...] ### Camera system\n\nThe iPhone 17 features a dual 48MP rear camera setup and an 18MP front camera. It supports 4K video recording with Dolby Vision, Smart HDR 5, and Night Mode for excellent results in all lighting conditions.\n\n|  |  |\n --- |\n| Feature | Details |\n| Rear cameras | 48MP main + 48MP ultra wide |\n| Front camera | 18MP centre stage |\n| Zoom | 2x optical zoom |\n| Video recording | 4K at 60fps, Dolby Vision |\n| Camera features | Night mode, Smart HDR 5, portrait mode | [...] |  |  |\n --- |\n| Feature | Details |\n| Display | 6.3-inch Super Retina XDR OLED, 120Hz ProMotion |\n| Resolution | 1206 x 2622 pixels |\n| Brightness | Up to 3,000 nits peak |\n| RAM | 8GB |\n| Storage options | 256GB, 512GB |\n| Front camera | 18MP Centre Stage, multi-aspect sensor |\n| Rear cameras | 48MP main + 48MP ultra wide |\n| Video recording | 4K at 60fps, Dolby Vision HDR |\n| Battery capacity | 3,692 mAh |\n| Charging | 50% in 20 minutes (wired), 50% in 30 minutes (wireless) |', 'score': 0.9170729, 'raw_content': None}, {'url': 'https://www.apple.com/in/iphone-17/specs/', 'title': 'iPhone 17 - Technical Specifications', 'content': '# iPhone 17 Technical Specifications\n\niPhone 17\n\nBlack, White, Mist Blue, Sage, Lavender\n\n Aluminium design\n Ceramic Shield 2 front\n Colour‑infused glass back (Black, Mist Blue, Sage, Lavender)\n\nCapacity1\n\n 256GB\n 512GB\n\nSize and Weight2\n\nWeight:\n\n177 g (6.24 oz.)\n\nDisplay [...] The iPhone 17 display has rounded corners that follow a beautiful curved design, and these corners are within a standard rectangle. When measured as a standard rectangular shape, the screen is 15.93 cm (6.27″) diagonally (actual viewable area is less).\n\nSplash, Water and Dust Resistant3\n\nRated IP68 (maximum depth of 6 metres up to 30 minutes) under IEC standard 60529\n\nApple Intelligence', 'score': 0.9037116, 'raw_content': None}, {'url': 'https://www.macrumors.com/roundup/iphone-17/', 'title': 'iPhone 17: Everything We Know', 'content': "Display\n\nThe iPhone 17 has an upgraded Super Retina XDR OLED display that's 6.3 inches, up from 6.1 inches. It features a resolution of 2622 × 1206 with 460 pixels per inch. Apple made major improvements to the iPhone 17's display, introducing ProMotion display technology with up to a 120Hz refresh rate. 120Hz maximum refresh rates allow for smoother scrolling when viewing webpages and improvements for video. [...] Aside from the slight size increase, the iPhone 17 is identical in design to the iPhone 16, featuring an aluminum frame, a frosted glass back, a vertical dual-lens camera bump, and the Dynamic Island. The Dynamic Island houses the front-facing TrueDepth camera and other sensors for Face ID biometric authentication. [...] The iPhone 17 is identical in design to the iPhone 16, but it is slightly larger. Instead of a 6.1-inch display, the iPhone 17 has a 6.3-inch display, making it the same size as the iPhone 17 Pro.\n\nAside from the size upgrade, there are no other design changes. The iPhone 17 measures in at 5.89 inches tall (149.6 mm), 2.81 inches wide (71.5 mm), and 0.31 inches deep (7.95mm). It weighs 177 grams. Compared to the iPhone 16, the iPhone 17 is a little thicker and it is sev ...

# %%
from tavily import TavilyClient
import os

# Test function with India location
def test_search(query: str):
    """Search the internet for information in India"""
    client = TavilyClient(api_key=os.getenv("TAVILY_API_KEY"))
    results = client.search(
        query=query, 
        max_results=5,
        search_depth="advanced",
        country="india"  
    )
    return results

# Test it
test_query = "iPhone 17 price in India"
print(f"🔍 Query: '{test_query}'\n")

results = test_search(test_query)



# Print Sources
print("┌" + "─"*68 + "┐")
print("│" + " "*18 + "📚 DETAILED SOURCES" + " "*30 + "│")
print("└" + "─"*68 + "┘")

for i, r in enumerate(results.get('results', []), 1):
    print(f"\n[{i}] {r['title']}")
    print(f"    {r['url']}")
    print(f"\n    {r['content']}\n")
    print("─"*70)

print("\n✅ Search completed!")
# Out:
# 🔍 Query: 'iPhone 17 price in India'
#
# ┌────────────────────────────────────────────────────────────────────┐
# │                  📚 DETAILED SOURCES                              │
# └────────────────────────────────────────────────────────────────────┘
#
# [1] Apple iPhone 17 - Price in India, Features and Specifications
#     https://www.bajajfinserv.in/apple-iphone-17-price-in-india
#
#     What is the price of the iPhone 17?
#
# The official prices in India are:
#
# |  |  |
#  --- |
# | Variant | Price (Rs.) |
# | iPhone 17 256GB | Rs. 82,900 |
# | iPhone 17 512GB | Rs. 1,02,900 |
#
# You can purchase the device on Easy EMIs using Bajaj Finserv or explore trade-in options for additional savings. Shop for this mobile phone with the Bajaj Finserv Insta EMI Card. Check your eligibility for it in just a few clicks and enjoy the freedom to split the cost into affordable EMIs. [...] |  |  |  |
#  ---
# | Model | Storage | Price (Rs.) |
# | iPhone 17 | 256GB | Rs. 82,900 |
# | iPhone 17 | 512GB | Rs. 1,02,900 |
#
# Disclaimer: Prices may vary over time, kindly refer to the official website for the most accurate and updated pricing.
#
# ──────────────────────────────────────────────────────────────────────
#
# [2] Apple iPhone 17 Price in India (2025)
#     https://www.reliancedigital.in/c/resource-center/bg/iphone-17-price-india
#
#     The lighter and more accessible option in the line-up is the Air. The iPhone 17 Air Price in India begins at ₹1,19,900 making it ideal for users who want high quality without stretching their budget.
#
# 3. iPhone 17 Pro Price in India
#
# Designed for performance and extra camera features, the Pro stands out for professionals and creators. The iPhone 17 Pro Price in India starts at ₹1,34,900 and varies based on storage, positioning it as the perfect middle ground between Air and Pro Max. [...] The iPhone 17 Price in India starts at around ₹82,900 for the base 256 GB variant. Higher storage options of 512 GB goes up to ₹1,02,900, giving customers flexible choices. Whether you pick the base version or the higher storage one, you’ll find the perfect fit for your needs at Reliance Digital.
#
# 2. iPhone 17 Air Price in India [...] The iPhone 17 Price in India starts at ₹82,900 for the base variant, with higher storage models priced accordingly, available at Reliance Digital online and in stores.
#
# 2. Will the iPhone 17 be cheaper in India?
#
# Apple pricing in India is usually higher than the US or Dubai due to import duties. Expect the iPhone 17 to cost slightly more here than in international markets.
#
# 3. How much is an iPhone 17 Pro Max?
#
# ──────────────────────────────────────────────────────────────────────
#
# [3] List of 7 Countries Where iPhone 17 is More Affordable ...
#     https://www.jagranjosh.com/general-knowledge/list-of-countries-where-iphone-17-is-cheaper-than-india-1820002783-1
#
#     Some of the main reasons behind the high pricing of iPhones in India include import duties, GST, shipping costs, and government tax policies in India. That is why the current pricing of the iPhone 17 in India starts from 82,900. Whereas, in various other countries, there are lower taxes, strong currencies which makes it a cheaper option in comparison to India. [...] | Country | iPhone 17 | iPhone 17 Pro | iPhone 17 Pro Max | iPhone Air |
# | United States | $799 (INR 70,468) | $1,099 (INR 96,927) | $1,199 (INR 1,05,747) | $999 (INR 88,107) |
# | Canada | CAD 1,129 (INR 72,128) | CAD 1,599 (INR 1,02,154) | CAD 1,749 (INR 1,11,737) | CAD 1,449 (INR 92,571) |
# | United Kingdom | £799 (INR 95,234) | £1,099 (INR 1,30,991) | £1,199 (INR 1,42,910) | £999 (INR 1,19,072) | [...] | Singapore | SGD 1,299 (INR 89,380) | SGD 1,749 (INR 1,20,344) | SGD 1,899 (INR 1,30,665) | SGD 1,599 (INR 1,10,022) |
# | Vietnam | VND 24,999,000 (INR 83,571) | VND 34,999,000 (INR 1,17,001) | VND 37,999,000 (INR 1,27,030) | VND 31,999,000 (INR 1,06,972) |
# | Dubai | AED 3,399 (INR 81,746) | AED 4,699 (INR 1,13,011) | AED 5,099 (INR 1,22,631) | AED 4,299 (INR 1,03,391) |
# | China | ¥5,999 (INR 74,482) | ¥8,999 (INR 1,11,729) | ¥9,999 (INR 1,24,144) | ¥7,999 (INR 99,313) |
#
# ──────────────────────────────────────────────────────────────────────
#
# [4] iphone 17 Price in India
#     https://idestiny.in/product/iphone-17/
#
#     Home
#  Products
#  iPhone
#  iPhone 17
#
# Sale !
#
# # iPhone 17
#
# ~~₹82,900~~ ₹3,000
#
# Ask the Expert
#
# Share
#
# #### Shipping Information
#
# ## Shipping Information
#
# #### Details
#
# ### Details
#
# |  |  |
#  --- |
# | Capacity | 128GB, 256GB, 512GB |
# | Color | Pink, Lavender, Mist Blue, Sage, Teal, Ultramarine, White, Black |
#
# ###### Overview
#
# DESCRIPTION [...] Select the fields to be shown. Others will be hidden. Drag and drop to rearrange the order.
#
#  Image
#  SKU
#  Rating
#  Price
#  Stock
#  Description
#  Weight
#  Dimensions
#  Additional information
#  Add to cart
#
# Click outside to hide the comparison bar
#
# Compare
#
# iPhone 17
#
# ~~₹82,900~~ ₹3,000
#
# #### Search our store
#
# 0
#
# Popular Searches: Headphone Tablet Mobile
#
# Results for ""
#
#  Pre-book
#  Deals
#  Open Box
#  iPhone
#   + ###### iPhone 17 Pro Max (New)
#
#     ###### iPhone 17 Pro (New)
#
#     ###### iPhone 17 (New) [...] ### iMac M3 – 24″ – Blue – Open Box
#
# ~~₹154,900~~ Original price was: ₹154,900.₹131,900Current price is: ₹131,900.
#
# Add to cart
#
# ### Get expert service and support
#
# Get a live demo on your desired Apple product at the comfort of your home. Book an appointment.
#
# ### Upgrade to the new
#
# Trade-in your old Notebook / Phone towards purchase of a newer Mac or iPhone.
#
# ### Fast, no‑contact delivery
#
# With convenient delivery and pickup methods, we’re making it easier and safer to shop at iDestiny.
#
# ──────────────────────────────────────────────────────────────────────
#
# [5] Apple iPhone 17 - Full Specifications & Price in India ...
#     https://www.91mobiles.com/apple-iphone-17-price-in-india
#
#     Add To Compare  See Full Specs
#
# ## Prices in India
#
# 8 GB + 256 GB
#
# ₹79,900 Go To Store
#
# 8 GB + 512 GB
#
# Starting at  ₹102,900  View All
#
# See All Prices
#
# ## Competitors For Apple iPhone 17
#
# View Alternatives
#
# Apple iPhone 16
#
# Available ₹69,499
#
# Buy From Amazon
#
# This Competitor Has
#
# Lower Weight: 170 grams vs 177 grams
#
# Lower Front Camera Resolution: 12 MP  vs 18 MP
#
# Smaller Screen: 6.1" (15.49 cm)  vs 6.3" (16.00 cm)
#
# Lower Brightness: 2000 nits  vs 3000 nits [...] | Chipset | Apple A19 |
# | CPU | Hexa Core (Dual core + Quad core) |
# | Architecture | 64 bit |
# | Fabrication | 3 nm |
# | Graphics (GPU) | Apple GPU (Five-core graphics) |
# | RAM | 8 GB |
# | RAM Type | LPDDR5X |
#
# ## Featured
#
# Apple iPhone 17
#
# ₹79,900
#
# Go To Store
#
# | Display | [...] Login/Signup
#
# # Apple iPhone 17
#
#  + Compare
#
# View All Photos (26)
#
# ₹79,900 (In Stock)
#
# Available in 1 store
#
# See Prices
#
# ## Key Specs
#
# iOS v26
#
# |  |
#
# ──────────────────────────────────────────────────────────────────────
#
# ✅ Search completed!

# %%
# ============================================
# CREATE TAVILY SEARCH TOOL
# ============================================

@tool("web_search")
def search(query: str) -> str:
    """Search the internet for information"""
    client = TavilyClient(api_key=os.getenv("TAVILY_API_KEY"))
    results = client.search(
        query=query, 
        max_results=5,
        search_depth="advanced",
        country="india"  
    )
    return "\n\n".join([f"Source: {r['title']}\n{r['content']}" for r in results.get('results', [])])

print("✓ Tavily Search Tool created successfully!")
print("✓ Agents can now search the web for real-time information\n")
# Out:
# ✓ Tavily Search Tool created successfully!
# ✓ Agents can now search the web for real-time information

# %%
# ============================================
# CREATE AI AGENTS
# ============================================

# Agent 1: Market Researcher (with web search capability)
market_researcher = Agent(
    role='Market Research Analyst',
    goal='Research iPhone 17 features, competitors, and target audience',
    backstory="""You are a senior market analyst specializing in smartphones.
    You analyze markets, identify target audiences, and understand what makes 
    products successful. You use web research to find the latest information.""",
    llm=llm,
    tools=[search],
    verbose=False
)

print("✓ Market Researcher Agent created")
# Out:
# ✓ Market Researcher Agent created

# %%
# Agent 2: Content Strategist
content_strategist = Agent(
    role='Content Strategist',
    goal='Create compelling marketing content for iPhone 17',
    backstory="""You are a creative strategist who knows how to make products 
    irresistible. You craft taglines, product descriptions, and key messages 
    that convert. You understand emotional storytelling.""",
    llm=llm,
    verbose=False
)

print("✓ Content Strategist Agent created")
# Out:
# ✓ Content Strategist Agent created

# %%
# Agent 3: Social Media Strategist
social_media_expert = Agent(
    role='Social Media Expert',
    goal='Design viral social media campaign for iPhone 17',
    backstory="""You are a social media guru who creates viral content. 
    You know what works on Instagram, Twitter, and TikTok. Your campaigns 
    get millions of views.""",
    llm=llm,
    verbose=False
)

print("✓ Social Media Expert Agent created")
# Out:
# ✓ Social Media Expert Agent created

# %%
#  Agent 4: EMAIL MARKETING AGENT
email_marketer = Agent(
    role='Email Marketing Specialist',
    goal='Create compelling marketing emails for iPhone 17 campaign',
    backstory="""You are an expert email marketer who knows how to write 
    emails that convert. You understand email psychology, subject line 
    optimization, and call-to-action design. You create personalized, 
    engaging emails that drive action.""",
    llm=llm,
    verbose=False
)

print("✓ Email Marketing Agent created")
# Out:
# ✓ Email Marketing Agent created

# %%
# ============================================
# DEFINE TASKS
# ============================================

# Task 1: Market Research (with web search)
research_task = Task(
    description="""Research iPhone 17 comprehensively:
    
    1. Search for "iPhone 17 features specifications" to find:
       - Camera capabilities
       - Battery life
       - Design and materials
       - Performance specs
    
    2. Search for "iPhone 17 competitors Samsung Google" to find:
       - Main competitors and their features
       - iPhone 17's competitive advantages
    
    3. Search for "premium smartphone buyers demographics 2025" to find:
       - Who buys premium phones
       - What they value most
    
    Provide a clear summary with:
    - Top 5 iPhone 17 features
    - 2 main competitors and how iPhone 17 beats them
    - Target audience profile (age, interests, income)
    """,
    agent=market_researcher,
    expected_output="""Detailed research report with:
    - 5 key iPhone 17 features
    - Competitive analysis
    - Target audience profile"""
)

print("✓ Research Task defined")
# Out:
# ✓ Research Task defined

# %%
# Task 2: Content Creation
content_task = Task(
    description="""Using the research, create:
    
    1. ONE powerful tagline (4-6 words max)
       - Must be emotional and memorable
       - Should highlight iPhone 17's uniqueness
    
    2. Product description (100 words)
       - Tell a story, don't just list specs
       - Connect features to emotions
       - Make people WANT it
    
    3. Three USPs (Unique Selling Points)
       - Each should be one sentence
       - Focus on benefits, not features
       - Example: "28-hour battery" becomes "Power that lasts from sunrise to midnight"
    """,
    agent=content_strategist,
    expected_output="""Complete content package with:
    - One tagline
    - Product description
    - Three USPs""",
    context=[research_task]
)

print("✓ Content Task defined")
# Out:
# ✓ Content Task defined

# %%
# Task 3: Social Media Campaign
social_task = Task(
    description="""Create a viral social media campaign:
    
    1. Three Instagram post ideas:
       - Each with a compelling caption
       - Include emojis and hashtags
       - Describe the visual
    
    2. One Twitter thread concept (5 tweets):
       - Hook in first tweet
       - Build interest through the thread
       - End with strong CTA
    
    Make everything designed to go viral!
    """,
    agent=social_media_expert,
    expected_output="""Social media campaign with:
    - 2 Instagram posts
    - 1 Twitter thread
    """,
    context=[research_task, content_task]
)

print("✓ Social Media Task defined")
# Out:
# ✓ Social Media Task defined

# %%
# Task 4: DEFINE EMAIL TASK 


email_task = Task(
    description="""Create a professional marketing email for iPhone 17 launch:
    
    1. Write a compelling subject line (5-8 words)
       - Must grab attention
       - Include urgency or benefit
       - Example: "iPhone 17 Pre-Orders: Your Exclusive Early Access"
    
    2. Email body (200-300 words)
       - Personalized greeting
       - Use the tagline and USPs from content creation
       - Include clear call-to-action (Pre-order button)
       - Add social proof or urgency
       - Professional signature
    
    3. Create two versions:
       - Version A: For existing Apple customers
       - Version B: For potential new customers
    
    Make it conversion-focused with clear next steps!
    """,
    agent=email_marketer,
    expected_output="""Complete email package with:
    - Subject line
    - Email body 
    - Two versions (A & B)
    - Call-to-action buttons""",
    context=[research_task, content_task, social_task]  # Uses all previous work
)

print("✓ Email Marketing Task defined")
# Out:
# ✓ Email Marketing Task defined

# %%
# ============================================
# CREATE UPDATED CREW (4 AGENTS)
# ============================================

iphone17_marketing_crew = Crew(
    agents=[
        market_researcher,      # Agent 1: Research
        content_strategist,     # Agent 2: Content
        social_media_expert,    # Agent 3: Social Media
        email_marketer         # Agent 4: Email Marketing 
    ],
    tasks=[
        research_task,          # Task 1: Market Research
        content_task,           # Task 2: Content Creation
        social_task,            # Task 3: Social Campaign
        email_task             # Task 4: Email Campaign 
    ],
    verbose=False
)

print("\n" + "="*70)
print("✓ Marketing Crew Assembled Successfully!")
print("="*70)
print("\n📋 Crew Configuration:")
print("  • 4 AI Agents (Research, Content, Social, Email)")
print("  • 4 Sequential Tasks")
print("  • LLM: Replicate OpenAI GPT")
print("  • Web Search: Tavily API")
print("  • Email: Gmail API via MCP")
print("\n🚀 Ready to generate complete campaign with email!")
# Out:
# ======================================================================
# ✓ Marketing Crew Assembled Successfully!
# ======================================================================
#
# 📋 Crew Configuration:
#   • 4 AI Agents (Research, Content, Social, Email)
#   • 4 Sequential Tasks
#   • LLM: Replicate OpenAI GPT
#   • Web Search: Tavily API
#   • Email: Gmail API via MCP
#
# 🚀 Ready to generate complete campaign with email!

# %%
# ============================================
# RUN CAMPAIGN WITH EMAIL
# ============================================

print("\n" + "="*70)
print("🚀 STARTING IPHONE 17 MARKETING CAMPAIGN (WITH EMAIL)")
print("="*70)
print("\n📊 Workflow:")
print("  Step 1: Market Research")
print("  Step 2: Content Creation")
print("  Step 3: Social Media Strategy")
print("  Step 4: Email Marketing Campaign (NEW)")
print("\n⏳ This will take 3-7 minutes...\n")
print("="*70 + "\n")

# Run the crew
result = iphone17_marketing_crew.kickoff()

# Display outputs for each step
print("\n\n" + "#"*70)
print("#" + " "*20 + "STEP 1: MARKET RESEARCH" + " "*25 + "#")
print("#"*70 + "\n")
if hasattr(research_task, 'output') and research_task.output:
    print(research_task.output.raw)

print("\n\n" + "#"*70)
print("#" + " "*20 + "STEP 2: CONTENT CREATION" + " "*24 + "#")
print("#"*70 + "\n")
if hasattr(content_task, 'output') and content_task.output:
    print(content_task.output.raw)

print("\n\n" + "#"*70)
print("#" + " "*17 + "STEP 3: SOCIAL MEDIA CAMPAIGN" + " "*21 + "#")
print("#"*70 + "\n")
if hasattr(social_task, 'output') and social_task.output:
    print(social_task.output.raw)

print("\n\n" + "#"*70)
print("#" + " "*18 + "STEP 4: EMAIL CAMPAIGN (NEW)" + " "*22 + "#")
print("#"*70 + "\n")
print(result)  # Final output contains email campaign

print("\n\n" + "="*70)
print("✅ COMPLETE CAMPAIGN GENERATED!")
print("="*70)
# Out:
# ======================================================================
# 🚀 STARTING IPHONE 17 MARKETING CAMPAIGN (WITH EMAIL)
# ======================================================================
#
# 📊 Workflow:
#   Step 1: Market Research
#   Step 2: Content Creation
#   Step 3: Social Media Strategy
#   Step 4: Email Marketing Campaign (NEW)
#
# ⏳ This will take 3-7 minutes...
#
# ======================================================================
#
#
#
# ######################################################################
# #                    STEP 1: MARKET RESEARCH                         #
# ######################################################################
#
# **iPhone 17 Key Features:**
# 1. **Camera Capabilities**: Dual 48MP rear cameras and an 18MP front camera, supporting 4K video recording with Dolby Vision, Smart HDR 5, and Night Mode.
# 2. **Display**: 6.3-inch Super Retina XDR OLED display with 120Hz adaptive refresh rate, HDR10, Dolby Vision support, and peak brightness of 3,000 nits.
# 3. **Design**: Aluminum frame with a ceramic shield front and color-infused glass back, rated IP68 for water and dust resistance.
# 4. **Performance**: Equipped with the A19 Pro chip, 8GB RAM, and available in 256GB and 512GB storage options, offering fast processing and AI capabilities.
# 5. **Battery Life**: 3,692 mAh battery with fast charging (50% in 20 minutes wired, 50% in 30 minutes wireless) and long-lasting performance.
#
# **Competitors and Competitive Advantages:**
# 1. **Samsung Galaxy S25 Ultra**:
#    - Features: Larger display with S Pen support, quad-camera setup, and superior multitasking capabilities.
#    - Competitive Advantage: iPhone 17 offers a brighter display, lighter design, and improved gaming stability with its A19 Pro chip.
#
# 2. **Google Pixel 10**:
#    - Features: Strong AI integration, excellent camera software, and competitive pricing.
#    - Competitive Advantage: iPhone 17 provides a more premium design, superior video recording capabilities, and a more robust ecosystem integration with other Apple products.
#
# **Target Audience Profile:**
# - **Age**: Predominantly 25-45 years old.
# - **Interests**: Technology enthusiasts, photography, content creation, and brand loyalty.
# - **Income**: Middle to high-income bracket, as they are willing to spend on premium features and brand prestige.
# - **Values**: They prioritize camera quality, battery life, display technology, and brand reputation when selecting a smartphone.
#
# This report provides a comprehensive overview of the iPhone 17's features, its competitive standing against major rivals, and insights into its target demographic. This information is crucial for understanding the market positioning and potential success of the iPhone 17 in the premium smartphone segment.
#
#
# ######################################################################
# #                    STEP 2: CONTENT CREATION                        #
# ######################################################################
#
# **Tagline:**
# "Capture Life in Unmatched Brilliance"
#
# **Product Description:**
# The iPhone 17 redefines what it means to capture and experience life’s moments. With its groundbreaking dual 48MP cameras, every snapshot tells a story in vibrant detail, while the 18MP front camera immortalizes your selfies in stunning 4K with Dolby Vision magic. Feel the colors pop on the 6.3-inch Super Retina XDR OLED display, offering an immersive viewing experience with a refresh rate that flows like a dream. Encased in a color-infused glass back and fortified by an aluminum frame, its exquisite design is both a statement and a shield against the elements. Powered by the lightning-fast A19 Pro chip, the iPhone 17 is your partner in creativity, delivering seamless performance that keeps pace with your passion. Dive into your world longer with battery life that empowers your adventures, charging to 50% in just 20 minutes. Elevate your everyday with the iPhone 17, where innovation meets inspiration.
#
# **Unique Selling Points (USPs):**
# 1. "Immortalize every moment with unparalleled clarity and color."
# 2. "Experience visuals as vivid as your imagination."
# 3. "Unleash your potential with performance that never pauses."
#
#
# ######################################################################
# #                 STEP 3: SOCIAL MEDIA CAMPAIGN                     #
# ######################################################################
#
# **Instagram Post Ideas:**
#
# 1. **Post 1:**
#    - **Visual:** A close-up shot of the iPhone 17 showcasing its dual 48MP rear cameras against a backdrop of vibrant nature scenery, highlighting the camera's capability to capture stunning photos.
#    - **Caption:** "Capture the world in its purest form 🌍📸. With the iPhone 17's dual 48MP cameras, every moment becomes a masterpiece. #CaptureBrilliance #iPhone17 #PhotographyGoals"
#    - **Hashtags:** #CaptureBrilliance #iPhone17 #PhotographyGoals #NaturePhotography #SmartphonePhotography
#    - **Emojis:** 🌍📸✨
#
# 2. **Post 2:**
#    - **Visual:** A dynamic video showcasing the iPhone 17's 6.3-inch Super Retina XDR OLED display, featuring a montage of vibrant videos and images playing on the screen to emphasize the display quality.
#    - **Caption:** "See your world in a new light 💡. The iPhone 17's Super Retina XDR display brings your favorite content to life with unmatched brightness and clarity. #VisualVibes #iPhone17 #DisplayMagic"
#    - **Hashtags:** #VisualVibes #iPhone17 #DisplayMagic #OLEDDisplay #TechInnovation
#    - **Emojis:** 💡✨📱
#
# 3. **Post 3:**
#    - **Visual:** A sleek image of the iPhone 17's design focusing on its color-infused glass back and aluminum frame, set against a minimalist background.
#    - **Caption:** "Design that speaks volumes 📱✨. The iPhone 17 combines elegance with durability, making it the perfect companion for your adventures. #DesignElegance #iPhone17 #TechStyle"
#    - **Hashtags:** #DesignElegance #iPhone17 #TechStyle #SmartphoneDesign #Innovation
#    - **Emojis:** 📱✨
#
# **Twitter Thread Concept:**
#
# 1. **Tweet 1 (Hook):** "Ready to redefine your smartphone experience? 📱✨ Meet the #iPhone17, where cutting-edge technology meets unparalleled design. Here's why it's a game-changer! 🧵👇 #Innovation"
#
# 2. **Tweet 2:** "Capture every detail with the iPhone 17's dual 48MP cameras! 📷 From stunning landscapes to vibrant selfies, your photos have never looked this good. #PhotographyGoals #CaptureBrilliance"
#
# 3. **Tweet 3:** "See the world in HDR with the Super Retina XDR display! 🌈 With 3,000 nits of peak brightness, your content shines brighter than ever. #DisplayMagic #VisualVibes"
#
# 4. **Tweet 4:** "Powered by the A19 Pro chip, the iPhone 17 delivers performance that keeps up with your pace. 🚀 Whether it's gaming or multitasking, experience seamless efficiency. #PerformancePower #TechInnovation"
#
# 5. **Tweet 5 (CTA):** "Don't just take our word for it, experience the magic yourself! ✨ Pre-order your #iPhone17 today and step into the future of smartphones. 📱🔗 [Link to pre-order] #UpgradeYourLife #iPhone17Magic"
#
# This campaign leverages visually stunning content and engaging captions to capture the attention of the target audience, encouraging them to explore the features and benefits of the iPhone 17.
#
#
# ######################################################################
# #                  STEP 4: EMAIL CAMPAIGN (NEW)                      #
# ######################################################################
#
# **Version A: For Existing Apple Customers**
#
# **Subject Line:** "Unlock the Future: iPhone 17 Awaits You!"
#
# **Email Body:**
#
# Hi [Customer Name],
#
# The moment you've been waiting for is finally here. As a valued member of the Apple family, we're thrilled to offer you an exclusive early access to the future of smartphones—the iPhone 17.
#
# "Capture Life in Unmatched Brilliance" with the iPhone 17. Whether you're an avid photographer or a tech enthusiast, our latest innovation has something for everyone. With dual 48MP cameras and an 18MP front camera, your memories will never look so vibrant and clear. Experience the world through our 6.3-inch Super Retina XDR OLED display that brings every scene to life with unmatched brightness and color accuracy.
#
# But the magic doesn't stop there. The iPhone 17 is powered by the A19 Pro chip, ensuring that your device keeps up with your pace, whether you're gaming, multitasking, or navigating your daily adventures. And with our fast-charging technology, you’ll never have to miss a moment.
#
# Join the ranks of those who redefine their smartphone experience. Pre-order your iPhone 17 now and step into a world of innovation and inspiration.
#
# [Pre-order Now]
#
# Thank you for choosing Apple. We can't wait for you to experience the iPhone 17.
#
# Best regards,
#
# [Your Name]
# Apple Marketing Team
#
# ---
#
# **Version B: For Potential New Customers**
#
# **Subject Line:** "Discover iPhone 17: Elevate Your Everyday"
#
# **Email Body:**
#
# Hello [Recipient Name],
#
# Are you ready to elevate your everyday experiences? Introducing the iPhone 17—a smartphone that merges cutting-edge technology with breathtaking design.
#
# "Capture Life in Unmatched Brilliance" is not just our tagline; it's our promise. With the iPhone 17, you're equipped with dual 48MP cameras that capture every moment in stunning detail and an 18MP front camera that makes your selfies shine. Enjoy visuals as vivid as your imagination on the 6.3-inch Super Retina XDR OLED display, featuring a refresh rate that flows like a dream.
#
# Designed for those who demand the best, the iPhone 17 is powered by the lightning-fast A19 Pro chip, ensuring seamless performance every step of the way. Plus, our fast-charging battery means you're always ready for action.
#
# Don't miss your chance to own a piece of the future. Pre-order the iPhone 17 today and experience why so many have chosen to join the Apple ecosystem.
#
# [Pre-order Now]
#
# We look forward to welcoming you to the Apple family.
#
# Kind regards,
#
# [Your Name]
# Apple Marketing Team
#
# Both versions are tailored to their respective audiences, highlighting the unique benefits of the iPhone 17 while encouraging immediate action with a clear call-to-action button.
#
#
# ======================================================================
# ✅ COMPLETE CAMPAIGN GENERATED!
# ======================================================================
# ╭────────────── Trace Batch Finalization ──────────────╮
# │ ✅ Trace batch finalized with session ID:            │
# │ ea3a34c0-6e54-4892-8e9e-4933995a1bc7                 │
# │                                                      │
# │ 🔗 View here:                                        │
# │ https://app.crewai.com/crewai_plus/ephemeral_trace_b │
# │ atches/ea3a34c0-6e54-4892-8e9e-4933995a1bc7?access_c │
# │ ode=TRACE-b4806bc0ce                                 │
# │ 🔑 Access Code: TRACE-b4806bc0ce                     │
# ╰──────────────────────────────────────────────────────╯
